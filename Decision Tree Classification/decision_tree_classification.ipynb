# %% [markdown]
# # Decision Tree Classification

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Data.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
print(X_train)
# Out:
# [[1 2 1 ... 'Yes' 'Yes' 'No']
#  [2 2 1 ... 'Not sure' 'Not sure' 'Yes']
#  [1 2 1 ... 'Yes' 'No' 'No']
#  ...
#  [1 2 2 ... 'No' 'Not sure' 'Not sure']
#  [1 1 2 ... 'No' 'Not sure' 'Not sure']
#  [1 2 2 ... 'No' 'Not sure' 'Not sure']]

# %%
print(y_train)
# Out:
# ['Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Doctor' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor'
#  'Doctor' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Doctor' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Doctor' 'Doctor'
#  'Doctor' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Doctor' 'Business Related Profession' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Doctor' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Doctor' 'Business Related Profession' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Doctor' 'Doctor'
#  'Doctor' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Doctor'
#  'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Doctor']

# %%
print(X_test)
# Out:
# [[1 2 1 ... 'Yes' 'Yes' 'Not sure']
#  [1 1 1 ... 'Yes' 'Yes' 'No']
#  [2 2 1 ... 'Yes' 'No' 'Yes']
#  ...
#  [1 2 2 ... 'Yes' 'No' 'No']
#  [2 2 1 ... 'No' 'Yes' 'No']
#  [1 1 2 ... 'No' 'Not sure' 'Not sure']]

# %%
print(y_test)
# Out:
# ['Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Doctor' 'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Doctor' 'Doctor' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Doctor' 'Doctor' 'Doctor' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor']

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()

X_train = ord_enc.fit_transform(X_train)

X_test = ord_enc.fit_transform(X_test)

# %%
print(X_train)
# Out:
# [[1. 2. 1. ... 2. 2. 0.]
#  [2. 2. 1. ... 1. 1. 2.]
#  [1. 2. 1. ... 2. 0. 0.]
#  ...
#  [1. 2. 2. ... 0. 1. 1.]
#  [1. 1. 2. ... 0. 1. 1.]
#  [1. 2. 2. ... 0. 1. 1.]]

# %%
print(X_test)
# Out:
# [[1. 2. 1. ... 2. 2. 1.]
#  [1. 1. 1. ... 2. 2. 0.]
#  [2. 2. 1. ... 2. 0. 2.]
#  ...
#  [1. 2. 2. ... 2. 0. 0.]
#  [2. 2. 1. ... 0. 2. 0.]
#  [1. 1. 2. ... 0. 1. 1.]]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train)
# Out:
# [[-0.31827242  1.09136097 -1.04918318 ...  1.14350448  0.81740805
#   -1.37186877]
#  [ 1.53255089  1.09136097 -1.04918318 ...  0.06071705 -0.51994151
#    1.12032068]
#  [-0.31827242  1.09136097 -1.04918318 ...  1.14350448 -1.85729107
#   -1.37186877]
#  ...
#  [-0.31827242  1.09136097  0.7104187  ... -1.02207038 -0.51994151
#   -0.12577405]
#  [-0.31827242 -0.27924494  0.7104187  ... -1.02207038 -0.51994151
#   -0.12577405]
#  [-0.31827242  1.09136097  0.7104187  ... -1.02207038 -0.51994151
#   -0.12577405]]

# %%
print(X_test)
# Out:
# [[-0.31827242  1.09136097 -1.04918318 ...  1.14350448  0.81740805
#   -0.12577405]
#  [-0.31827242 -0.27924494 -1.04918318 ...  1.14350448  0.81740805
#   -1.37186877]
#  [ 1.53255089  1.09136097 -1.04918318 ...  1.14350448 -1.85729107
#    1.12032068]
#  ...
#  [-0.31827242  1.09136097  0.7104187  ...  1.14350448 -1.85729107
#   -1.37186877]
#  [ 1.53255089  1.09136097 -1.04918318 ... -1.02207038  0.81740805
#   -1.37186877]
#  [-0.31827242 -0.27924494  0.7104187  ... -1.02207038 -0.51994151
#   -0.12577405]]

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay, f1_score, recall_score, precision_score
cm = confusion_matrix(y_test, y_pred, labels=classifier.classes_)
print(cm)
print(precision_score(y_test, y_pred, average='weighted'))
print(recall_score(y_test, y_pred, average='weighted'))
print(accuracy_score(y_test, y_pred))
print(f1_score(y_test, y_pred, average='weighted'))
# Out:
# [[36  0  7]
#  [ 1 43  0]
#  [ 7  2 83]]
# 0.90542294452909
# 0.9050279329608939
# 0.9050279329608939
# 0.9051125628001336

# %%
displ = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
_, ax = plt.subplots(figsize=(10,10))
displ.plot(cmap="Greens", ax=ax)
plt.show()
displ = ConfusionMatrixDisplay(confusion_matrix=cm/np.sum(cm), display_labels=classifier.classes_)
_, ax = plt.subplots(figsize=(10,10))
displ.plot(cmap="Blues", values_format='.2%', ax=ax)
plt.show()
