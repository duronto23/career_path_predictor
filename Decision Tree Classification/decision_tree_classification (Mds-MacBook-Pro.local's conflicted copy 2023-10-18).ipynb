# %% [markdown]
# # Decision Tree Classification

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Data.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
print(X_train)
# Out:
# [[0 2 2 ... 'Not sure' 'Yes' 'Yes']
#  [1 0 2 ... 'No' 'Not sure' 'Not sure']
#  [1 2 2 ... 'Yes' 'Yes' 'No']
#  ...
#  [1 2 2 ... 'Yes' 'Yes' 'Yes']
#  [2 1 1 ... 'Yes' 'Not sure' 'Not sure']
#  [1 2 2 ... 'Yes' 'No' 'No']]

# %%
print(y_train)
# Out:
# ['Engineer' 'Engineer' 'Business Related Profession' 'Doctor' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Business Related Profession'
#  'Doctor' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Doctor' 'Doctor' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Doctor' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Doctor' 'Doctor' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Doctor' 'Doctor' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Doctor' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Doctor'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Doctor' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Doctor'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Doctor' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession']

# %%
print(X_test)
# Out:
# [[1 1 2 ... 'Yes' 'Yes' 'No']
#  [1 2 2 ... 'No' 'Not sure' 'Not sure']
#  [2 0 2 ... 'Yes' 'Not sure' 'Yes']
#  ...
#  [0 2 1 ... 'Yes' 'No' 'No']
#  [1 2 2 ... 'No' 'Not sure' 'Not sure']
#  [1 1 2 ... 'Not sure' 'No' 'Yes']]

# %%
print(y_test)
# Out:
# ['Engineer' 'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Doctor' 'Engineer' 'Doctor'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer']

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()

X_train = ord_enc.fit_transform(X_train)

X_test = ord_enc.fit_transform(X_test)

# %%
print(X_train)
# Out:
# [[0. 2. 2. ... 1. 2. 2.]
#  [1. 0. 2. ... 0. 1. 1.]
#  [1. 2. 2. ... 2. 2. 0.]
#  ...
#  [1. 2. 2. ... 2. 2. 2.]
#  [2. 1. 1. ... 2. 1. 1.]
#  [1. 2. 2. ... 2. 0. 0.]]

# %%
print(X_test)
# Out:
# [[1. 1. 2. ... 2. 2. 0.]
#  [1. 2. 2. ... 0. 1. 1.]
#  [2. 0. 2. ... 2. 1. 2.]
#  ...
#  [0. 2. 1. ... 2. 0. 0.]
#  [1. 2. 2. ... 0. 1. 1.]
#  [1. 1. 2. ... 1. 0. 2.]]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train)
# Out:
# [[-2.18798419  1.09753746  0.7406586  ...  0.06394554  0.84883669
#    1.20278884]
#  [-0.3474629  -1.72545553  0.7406586  ... -1.00514398 -0.48291589
#   -0.06143912]
#  [-0.3474629   1.09753746  0.7406586  ...  1.13303507  0.84883669
#   -1.32566707]
#  ...
#  [-0.3474629   1.09753746  0.7406586  ...  1.13303507  0.84883669
#    1.20278884]
#  [ 1.4930584  -0.31395903 -0.96732567 ...  1.13303507 -0.48291589
#   -0.06143912]
#  [-0.3474629   1.09753746  0.7406586  ...  1.13303507 -1.81466846
#   -1.32566707]]

# %%
print(X_test)
# Out:
# [[-0.3474629  -0.31395903  0.7406586  ...  1.13303507  0.84883669
#   -1.32566707]
#  [-0.3474629   1.09753746  0.7406586  ... -1.00514398 -0.48291589
#   -0.06143912]
#  [ 1.4930584  -1.72545553  0.7406586  ...  1.13303507 -0.48291589
#    1.20278884]
#  ...
#  [-2.18798419  1.09753746 -0.96732567 ...  1.13303507 -1.81466846
#   -1.32566707]
#  [-0.3474629   1.09753746  0.7406586  ... -1.00514398 -0.48291589
#   -0.06143912]
#  [-0.3474629  -0.31395903  0.7406586  ...  0.06394554 -1.81466846
#    1.20278884]]

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred, labels=classifier.classes_)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[29  1  5]
#  [ 2 41  2]
#  [ 5  1 93]]
# 0.9106145251396648

# %%
displ = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
_, ax = plt.subplots(figsize=(10,10))
displ.plot(cmap="Greens", ax=ax)
plt.show()
displ = ConfusionMatrixDisplay(confusion_matrix=cm/np.sum(cm), display_labels=classifier.classes_)
_, ax = plt.subplots(figsize=(10,10))
displ.plot(cmap="Blues", values_format='.2%', ax=ax)
plt.show()
