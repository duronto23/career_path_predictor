# %% [markdown]
# # Random Forest Classification

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Data.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
print(X_train)
# Out:
# [[0 1 2 ... 'Yes' 'Yes' 'No']
#  [2 1 0 ... 'Yes' 'Yes' 'Yes']
#  [1 2 2 ... 'No' 'Not sure' 'Not sure']
#  ...
#  [2 0 2 ... 'Yes' 'Yes' 'Not sure']
#  [1 1 2 ... 'No' 'Not sure' 'Not sure']
#  [1 2 2 ... 'Yes' 'No' 'Yes']]

# %%
print(y_train)
# Out:
# ['Doctor' 'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Doctor' 'Engineer' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Doctor'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Doctor' 'Business Related Profession' 'Doctor'
#  'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Doctor' 'Doctor' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Doctor' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Doctor' 'Doctor'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Business Related Profession']

# %%
print(X_test)
# Out:
# [[2 1 1 ... 'Yes' 'No' 'Yes']
#  [1 2 1 ... 'No' 'Not sure' 'No']
#  [1 2 2 ... 'No' 'Yes' 'No']
#  ...
#  [2 0 1 ... 'Yes' 'Yes' 'Yes']
#  [1 2 2 ... 'No' 'Not sure' 'Not sure']
#  [1 0 2 ... 'Yes' 'Yes' 'Yes']]

# %%
print(y_test)
# Out:
# ['Engineer' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Doctor' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Doctor' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Doctor' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Business Related Profession'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer']

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()

X_train = ord_enc.fit_transform(X_train)

X_test = ord_enc.fit_transform(X_test)

# %%
print(X_train)
# Out:
# [[0. 1. 2. ... 2. 2. 0.]
#  [2. 1. 0. ... 2. 2. 2.]
#  [1. 2. 2. ... 0. 1. 1.]
#  ...
#  [2. 0. 2. ... 2. 2. 1.]
#  [1. 1. 2. ... 0. 1. 1.]
#  [1. 2. 2. ... 2. 0. 2.]]

# %%
print(X_test)
# Out:
# [[2. 1. 1. ... 2. 0. 2.]
#  [1. 2. 1. ... 0. 1. 0.]
#  [1. 2. 2. ... 0. 2. 0.]
#  ...
#  [2. 0. 1. ... 2. 2. 2.]
#  [1. 2. 2. ... 0. 1. 1.]
#  [1. 0. 2. ... 2. 2. 2.]]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train)
# Out:
# [[-2.25246434 -0.31050922  0.72320833 ...  1.11459616  0.84401996
#   -1.3895155 ]
#  [ 1.48998418 -0.31050922 -2.70083111 ...  1.11459616  0.84401996
#    1.12618938]
#  [-0.38124008  1.08547761  0.72320833 ... -1.01507865 -0.45727883
#   -0.13166306]
#  ...
#  [ 1.48998418 -1.70649605  0.72320833 ...  1.11459616  0.84401996
#   -0.13166306]
#  [-0.38124008 -0.31050922  0.72320833 ... -1.01507865 -0.45727883
#   -0.13166306]
#  [-0.38124008  1.08547761  0.72320833 ...  1.11459616 -1.75857761
#    1.12618938]]

# %%
print(X_test)
# Out:
# [[ 1.48998418 -0.31050922 -0.98881139 ...  1.11459616 -1.75857761
#    1.12618938]
#  [-0.38124008  1.08547761 -0.98881139 ... -1.01507865 -0.45727883
#   -1.3895155 ]
#  [-0.38124008  1.08547761  0.72320833 ... -1.01507865  0.84401996
#   -1.3895155 ]
#  ...
#  [ 1.48998418 -1.70649605 -0.98881139 ...  1.11459616  0.84401996
#    1.12618938]
#  [-0.38124008  1.08547761  0.72320833 ... -1.01507865 -0.45727883
#   -0.13166306]
#  [-0.38124008 -1.70649605  0.72320833 ...  1.11459616  0.84401996
#    1.12618938]]

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay, f1_score, recall_score, precision_score
cm = confusion_matrix(y_test, y_pred, labels=classifier.classes_)
print(cm)
print(precision_score(y_test, y_pred, average='weighted'))
print(recall_score(y_test, y_pred, average='weighted'))
print(accuracy_score(y_test, y_pred))
print(f1_score(y_test, y_pred, average='weighted'))
# Out:
# [[32  0  2]
#  [ 0 48  3]
#  [ 4  0 90]]
# 0.951256166486981
# 0.9497206703910615
# 0.9497206703910615
# 0.9500785992406103

# %%
displ = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
_, ax = plt.subplots(figsize=(10,10))
displ.plot(cmap="Greens", ax=ax)
plt.show()
displ = ConfusionMatrixDisplay(confusion_matrix=cm/np.sum(cm), display_labels=classifier.classes_)
_, ax = plt.subplots(figsize=(10,10))
displ.plot(cmap="Blues", values_format='.2%', ax=ax)
plt.show()
