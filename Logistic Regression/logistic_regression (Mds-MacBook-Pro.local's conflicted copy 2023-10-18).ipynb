# %% [markdown]
# # Logistic Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Data.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
print(X_train)
# Out:
# [[1 2 2 ... 'Yes' 'Yes' 'Yes']
#  [1 1 2 ... 'Yes' 'No' 'Not sure']
#  [1 2 2 ... 'Yes' 'No' 'Yes']
#  ...
#  [1 2 1 ... 'Yes' 'No' 'Yes']
#  [1 1 2 ... 'No' 'Not sure' 'Not sure']
#  [1 0 1 ... 'Not sure' 'Yes' 'No']]

# %%
print(y_train)
# Out:
# ['Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Doctor'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Doctor' 'Doctor' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Engineer' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Doctor' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Doctor' 'Doctor' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Doctor' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Engineer']

# %%
print(X_test)
# Out:
# [[1 2 2 ... 'Not sure' 'Yes' 'No']
#  [2 1 1 ... 'Yes' 'No' 'Not sure']
#  [2 0 1 ... 'Yes' 'Yes' 'Yes']
#  ...
#  [2 2 2 ... 'Yes' 'Yes' 'Yes']
#  [1 1 2 ... 'No' 'Not sure' 'Not sure']
#  [1 2 1 ... 'Yes' 'No' 'No']]

# %%
print(y_test)
# Out:
# ['Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Doctor'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Doctor' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Doctor' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Doctor' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Business Related Profession']

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()

X_train = ord_enc.fit_transform(X_train)

X_test = ord_enc.fit_transform(X_test)

# %%
print(X_train)
# Out:
# [[1. 2. 2. ... 2. 2. 2.]
#  [1. 1. 2. ... 2. 0. 1.]
#  [1. 2. 2. ... 2. 0. 2.]
#  ...
#  [1. 2. 1. ... 2. 0. 2.]
#  [1. 1. 2. ... 0. 1. 1.]
#  [1. 0. 1. ... 1. 2. 0.]]

# %%
print(X_test)
# Out:
# [[1. 2. 2. ... 1. 2. 0.]
#  [2. 1. 1. ... 2. 0. 1.]
#  [2. 0. 1. ... 2. 2. 2.]
#  ...
#  [2. 2. 2. ... 2. 2. 2.]
#  [1. 1. 2. ... 0. 1. 1.]
#  [1. 2. 1. ... 2. 0. 0.]]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train)
# Out:
# [[-0.3835531   1.13056159  0.73482053 ...  1.10975009  0.85813172
#    1.11348232]
#  [-0.3835531  -0.27606736  0.73482053 ...  1.10975009 -1.75782537
#   -0.12758652]
#  [-0.3835531   1.13056159  0.73482053 ...  1.10975009 -1.75782537
#    1.11348232]
#  ...
#  [-0.3835531   1.13056159 -0.97443592 ...  1.10975009 -1.75782537
#    1.11348232]
#  [-0.3835531  -0.27606736  0.73482053 ... -1.04139591 -0.44984683
#   -0.12758652]
#  [-0.3835531  -1.68269631 -0.97443592 ...  0.03417709  0.85813172
#   -1.36865535]]

# %%
print(X_test)
# Out:
# [[-0.3835531   1.13056159  0.73482053 ...  0.03417709  0.85813172
#   -1.36865535]
#  [ 1.51645533 -0.27606736 -0.97443592 ...  1.10975009 -1.75782537
#   -0.12758652]
#  [ 1.51645533 -1.68269631 -0.97443592 ...  1.10975009  0.85813172
#    1.11348232]
#  ...
#  [ 1.51645533  1.13056159  0.73482053 ...  1.10975009  0.85813172
#    1.11348232]
#  [-0.3835531  -0.27606736  0.73482053 ... -1.04139591 -0.44984683
#   -0.12758652]
#  [-0.3835531   1.13056159 -0.97443592 ...  1.10975009 -1.75782537
#   -1.36865535]]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred, labels=classifier.classes_)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[29  0  9]
#  [ 0 49  3]
#  [ 7  0 82]]
# 0.8938547486033519

# %%
displ = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
_, ax = plt.subplots(figsize=(10,10))
displ.plot(cmap="Greens", ax=ax)
plt.show()
displ = ConfusionMatrixDisplay(confusion_matrix=cm/np.sum(cm), display_labels=classifier.classes_)
_, ax = plt.subplots(figsize=(10,10))
displ.plot(cmap="Blues", values_format='.2%', ax=ax)
plt.show()
