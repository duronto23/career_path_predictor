# %% [markdown]
# # Logistic Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Data.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
print(X_train)
# Out:
# [[2 1 2 ... 'No' 'No' 'No']
#  [1 1 1 ... 'Yes' 'Yes' 'No']
#  [1 2 2 ... 'No' 'Not sure' 'Not sure']
#  ...
#  [1 1 2 ... 'No' 'Not sure' 'Not sure']
#  [1 1 2 ... 'No' 'Not sure' 'Not sure']
#  [1 1 2 ... 'Yes' 'Yes' 'No']]

# %%
print(y_train)
# Out:
# ['Engineer' 'Engineer' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Doctor' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Doctor' 'Doctor'
#  'Doctor' 'Doctor' 'Doctor' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Doctor' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Doctor' 'Doctor' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Doctor' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Doctor' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Doctor' 'Doctor' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Doctor' 'Doctor'
#  'Engineer' 'Business Related Profession' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Engineer' 'Doctor'
#  'Doctor' 'Doctor' 'Engineer']

# %%
print(X_test)
# Out:
# [[0 1 2 ... 'Yes' 'Not sure' 'Not sure']
#  [1 1 1 ... 'Yes' 'Yes' 'Yes']
#  [0 1 2 ... 'Yes' 'Yes' 'Yes']
#  ...
#  [2 1 2 ... 'No' 'Yes' 'Yes']
#  [0 1 2 ... 'Not sure' 'Not sure' 'No']
#  [1 2 2 ... 'No' 'Not sure' 'Not sure']]

# %%
print(y_test)
# Out:
# ['Business Related Profession' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Doctor' 'Engineer' 'Business Related Profession' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Business Related Profession' 'Business Related Profession'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Doctor' 'Doctor'
#  'Engineer' 'Engineer' 'Doctor' 'Business Related Profession' 'Doctor'
#  'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Engineer' 'Engineer' 'Business Related Profession'
#  'Engineer' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Doctor' 'Business Related Profession' 'Engineer' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Engineer' 'Engineer' 'Business Related Profession' 'Doctor' 'Doctor'
#  'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Business Related Profession' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Doctor'
#  'Business Related Profession' 'Business Related Profession'
#  'Business Related Profession' 'Engineer' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Doctor' 'Engineer' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Business Related Profession'
#  'Engineer' 'Doctor' 'Engineer' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Engineer' 'Doctor' 'Doctor' 'Engineer' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Engineer' 'Doctor' 'Doctor' 'Engineer'
#  'Business Related Profession' 'Doctor' 'Doctor' 'Doctor'
#  'Business Related Profession' 'Doctor' 'Engineer' 'Engineer' 'Engineer'
#  'Doctor']

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()

X_train = ord_enc.fit_transform(X_train)

X_test = ord_enc.fit_transform(X_test)

# %%
print(X_train)
# Out:
# [[2. 1. 2. ... 0. 0. 0.]
#  [1. 1. 1. ... 2. 2. 0.]
#  [1. 2. 2. ... 0. 1. 1.]
#  ...
#  [1. 1. 2. ... 0. 1. 1.]
#  [1. 1. 2. ... 0. 1. 1.]
#  [1. 1. 2. ... 2. 2. 0.]]

# %%
print(X_test)
# Out:
# [[0. 1. 2. ... 2. 1. 1.]
#  [1. 1. 1. ... 2. 2. 2.]
#  [0. 1. 2. ... 2. 2. 2.]
#  ...
#  [2. 1. 2. ... 0. 2. 2.]
#  [0. 1. 2. ... 1. 1. 0.]
#  [1. 2. 2. ... 0. 1. 1.]]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train)
# Out:
# [[ 1.54269734 -0.33240151  0.75478373 ... -1.04918318 -1.65784033
#   -1.29878511]
#  [-0.35901482 -0.33240151 -0.97089702 ...  1.10144134  0.88354814
#   -1.29878511]
#  [-0.35901482  1.06787258  0.75478373 ... -1.04918318 -0.38714609
#   -0.06019325]
#  ...
#  [-0.35901482 -0.33240151  0.75478373 ... -1.04918318 -0.38714609
#   -0.06019325]
#  [-0.35901482 -0.33240151  0.75478373 ... -1.04918318 -0.38714609
#   -0.06019325]
#  [-0.35901482 -0.33240151  0.75478373 ...  1.10144134  0.88354814
#   -1.29878511]]

# %%
print(X_test)
# Out:
# [[-2.26072698 -0.33240151  0.75478373 ...  1.10144134 -0.38714609
#   -0.06019325]
#  [-0.35901482 -0.33240151 -0.97089702 ...  1.10144134  0.88354814
#    1.17839861]
#  [-2.26072698 -0.33240151  0.75478373 ...  1.10144134  0.88354814
#    1.17839861]
#  ...
#  [ 1.54269734 -0.33240151  0.75478373 ... -1.04918318  0.88354814
#    1.17839861]
#  [-2.26072698 -0.33240151  0.75478373 ...  0.02612908 -0.38714609
#   -1.29878511]
#  [-0.35901482  1.06787258  0.75478373 ... -1.04918318 -0.38714609
#   -0.06019325]]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Business Related Profession']
#  ['Business Related Profession' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Business Related Profession']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Doctor' 'Doctor']
#  ['Business Related Profession' 'Business Related Profession']
#  ['Business Related Profession' 'Doctor']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Engineer' 'Engineer']
#  ['Doctor' 'Doctor']]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay, f1_score, recall_score, precision_score
cm = confusion_matrix(y_test, y_pred, labels=classifier.classes_)
print(cm)
print(precision_score(y_test, y_pred, average='weighted'))
print(recall_score(y_test, y_pred, average='weighted'))
print(accuracy_score(y_test, y_pred))
print(f1_score(y_test, y_pred, average='weighted'))
# Out:
# [[25  1  4]
#  [ 2 45  0]
#  [10  0 92]]
# 0.9161929113957291
# 0.9050279329608939
# 0.9050279329608939
# 0.9087140193134818

# %%
displ = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
_, ax = plt.subplots(figsize=(10,10))
displ.plot(cmap="Greens", ax=ax)
plt.show()
displ = ConfusionMatrixDisplay(confusion_matrix=cm/np.sum(cm), display_labels=classifier.classes_)
_, ax = plt.subplots(figsize=(10,10))
displ.plot(cmap="Blues", values_format='.2%', ax=ax)
plt.show()
